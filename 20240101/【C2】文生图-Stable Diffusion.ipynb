# %% [markdown]
# # 文生图-Stable Diffusion
#
# 同济子豪兄 2024-1-1

# %% [markdown]
# ## 导入工具包

# %%
# Python 标准库
import json
import io

# AWS 服务
import boto3
from botocore.config import Config

# 图像处理
from PIL import Image
import base64

# %% [markdown]
# ## 指定AWS Key
#
# 注册AWS IAM账号时生成的秘钥，需要换成你自己的

# %%
aws_access_key_id = 'XXXXXXX'
aws_secret_access_key = 'XXXXXXX'

# %% [markdown]
# ## 指定AWS区域
#
# 默认使用`美国东部（弗吉尼亚北部）`，也就是`us-east-1`

# %%
aws_config = Config(
    region_name='us-east-1',
    proxies={},
)

# %% [markdown]
# ## 创建Bedrock Client

# %%
bedrock_runtime = boto3.client(
    service_name='bedrock-runtime',
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    config=aws_config,
)
# Out:
# /environment/miniconda3/lib/python3.7/site-packages/boto3/compat.py:82: PythonDeprecationWarning: Boto3 will no longer support Python 3.7 starting December 13, 2023. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.8 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)

# %% [markdown]
# ## 选择文生图模型

# %%
model_id = 'stability.stable-diffusion-xl-v1'

# %% [markdown]
# ## 文生图提示词（可以换成你自己的提示词）

# %%
prompt = 'A panda is playing football'

# prompt = 'A panda is playing basketball'

# prompt = 'A panda is eating KFC'

# prompt = 'green iguana'

# prompt = 'A girl is playing the piano, anime style'

# prompt = 'little red riding hood walking in forest carrying basket'

# %% [markdown]
# ## 调用Amazon Bedrock基础模型API，生成图像
#
# 文档：https://docs.aws.amazon.com/bedrock/latest/userguide/model-parameters-diffusion-1-0-text-image.html

# %%
body = json.dumps(
    {
        "text_prompts": [{"text": prompt}],    # 文生图提示词
        "cfg_scale": 10,                       # 生成的图像内容有多贴近提示词
        "seed": 1,                             # 随机种子，便于复现
        "steps": 50,                           # 生成图像的迭代次数
        "samples": 1,                          # 生成图像数量
        "style_preset": "anime",               # 预设风格
    }
)

response = bedrock_runtime.invoke_model(
    body=body,
    modelId=model_id,
    accept="application/json",
    contentType="application/json",
)
response_body = json.loads(response.get("body").read())
print(response_body["result"])
# Out:
# success

# %% [markdown]
# ## 对API生成的图像做解码，获得图像内容

# %%
base64_image = response_body.get("artifacts")[0].get("base64")
base64_bytes = base64_image.encode("ascii")
image_bytes = base64.b64decode(base64_bytes)
image = Image.open(io.BytesIO(image_bytes))

# %% [markdown]
# ## 查看生成的图像内容

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024 at 0x7F09F2B158D0>

# %% [markdown]
# ## 保存图像

# %%
image.save('outputs/C1_football.jpg')
